# %%
#importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargamos archivo
data = pd.read_csv('Albany.csv')
data.head(5)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  2992450  https://www.airbnb.com/rooms/2992450  20241105062440   2024-11-05
# 1  3820211  https://www.airbnb.com/rooms/3820211  20241105062440   2024-11-05
# 2  5651579  https://www.airbnb.com/rooms/5651579  20241105062440   2024-11-05
# 3  6623339  https://www.airbnb.com/rooms/6623339  20241105062440   2024-11-05
# 4  9005989  https://www.airbnb.com/rooms/9005989  20241105062440   2024-11-05
#
#             source                                              name  \
# 0      city scrape                        Luxury 2 bedroom apartment
# 1  previous scrape         Restored Precinct in Center Sq. w/Parking
# 2      city scrape        Large studio apt  by Capital Center & ESP@
# 3      city scrape  Center Sq. Loft in Converted Precinct w/ Parking
# 4      city scrape    Studio in The heart of Center SQ, in Albany NY
#
#                                          description  \
# ...

# %%
#Eliminar columnas innecesarias
#axis = 1 para columnas
#axis = 0 para filas
data2 = data.drop(['description', 'host_thumbnail_url', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30', 'availability_60', 'availability_90', 'calendar_last_scraped', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review', 'last_review', 'review_scores_accuracy', 'review_scores_checkin', 'review_scores_value', 'license', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'neighbourhood_group_cleansed'], axis=1)
data2
# Out:
#                       id                                       listing_url  \
# 0                2992450              https://www.airbnb.com/rooms/2992450
# 1                3820211              https://www.airbnb.com/rooms/3820211
# 2                5651579              https://www.airbnb.com/rooms/5651579
# 3                6623339              https://www.airbnb.com/rooms/6623339
# 4                9005989              https://www.airbnb.com/rooms/9005989
# ..                   ...                                               ...
# 416  1277527400878120655  https://www.airbnb.com/rooms/1277527400878120655
# 417  1277717926531215616  https://www.airbnb.com/rooms/1277717926531215616
# 418  1279011643102137684  https://www.airbnb.com/rooms/1279011643102137684
# 419  1279781671588026640  https://www.airbnb.com/rooms/1279781671588026640
# 420  1279846646046615122  https://www.airbnb.com/rooms/1279846646046615122
#
#           scrape_id last_scraped           source  \
# ...

# %%
#Realizamos una copia del dataframe
dataN=data2.copy()

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN["neighborhood_overview"] =dataN["neighborhood_overview"].fillna("nice")

#Descripción: se usa el cuarto método de sustitución de valores, en la columna "neighborhood_overview"
#pues esta columna contiene strings y se colocó un string "nice" para que todos los vecindarios sean lindos o por 
#lo que espera el cliente

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante "Forward fill" "(ffill)"
#Filtro por columnas
dataN["host_location"] =dataN["host_location"].fillna(method="ffill")

#Descripción: se usa el secto método de sustitución de valores nulos para "host_location", pues sabemos que la mayor
#parte de los airbnb están localizados en Albany, NY; y se asume que lo más probable es que el siguiente 
#también esté localizado en Albany, NY
# Out:
# C:\Users\ady_b\AppData\Local\Temp\ipykernel_5000\1842374782.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataN["host_location"] =dataN["host_location"].fillna(method="ffill")

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN["host_about"] =dataN["host_about"].fillna("Hi! I'm a person who loves to travel and enjoys spending time learning about other cultures..")

#Descripción: se usa el cuarto método de sustitución de valores, en la columna "host_about"
#pues esta columna contiene strings y se colocó un string "Hi! I'm a person who loves to travel and enjoys spending time learning about other cultures.." para que todos los 
#host tengan una buena presentación

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN["host_response_time"] = dataN["host_response_time"].fillna("unknown")

#Descripcion: se usa el cuarto método de sustitución de valores, en la columna "host_response_time"
#pues esta columna contiene strings y se coloca "unknown" para indicar al cliente que es un dato desconocido

# %%
#Primer Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
data2["host_response_rate"] = data2["host_response_rate"].str.rstrip('%').astype(float) / 100
dataN["host_response_rate"]=dataN["host_response_rate"].fillna(round(data2["host_response_rate"].mean(),1))

#Descripción: sustituimos los valores nulos con el promedio ya que al tratarse de una medida de tipo entero esto facilita
#el manejo de la variable "host_response_rate". Es importante mencionar que el prorecntaje se pasa a flotante

# %%
#Primer Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
data2["host_acceptance_rate"] = data2["host_acceptance_rate"].str.rstrip('%').astype(float) / 100
dataN["host_acceptance_rate"]=dataN["host_acceptance_rate"].fillna(round(data2["host_acceptance_rate"].mean(),1))

#Descripción: primero convertimos los datos de string a float, y usamos el primer método de sustitución de valores nulos, 
#pues es más fácil trabajar con el promedio en la columna "host_acceptance_rate"

# %%
#Quinto método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante "Forward fill" "(ffill)"
#Filtro por columnas
dataN['host_is_superhost']=dataN['host_is_superhost'].fillna(method=("ffill"))

#Descripción: usamos el quinto método de sustitución de valores nulos en la columna "host_is_superhost". 
#hicimos uso de ffill para completa el valor faltante con el último valor válido anterior pues no hay tanta 
#diferencia de datos
# Out:
# C:\Users\ady_b\AppData\Local\Temp\ipykernel_5000\1685551699.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataN['host_is_superhost']=dataN['host_is_superhost'].fillna(method=("ffill"))

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN['host_neighbourhood'] = dataN['host_neighbourhood'].fillna("unknown")

#Descripción: se usa el cuarto método de sustitución de valores nulos, pues por seguridad colocamos "unknwon"
#en la columna "host_neighbourhood"

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN["neighbourhood"] = dataN["neighbourhood"].fillna("Neighborhood highlights")

#Descripción: se usa el cuarto método de sustitución de valores nulos en la columna de "neighbourhood", pues podemos 
#asumir que los valores nulos serán iguales a "Neighborhood highlights", ya que la mayoría de registros son iguales.

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en concreto
dataN["bathrooms"]=data2["bathrooms"].fillna(1)

#Descripcion: Se uso el tercer metodo de sustitucion para los registros de la columna "bathrooms", 
# pues este método nos ayuda a poner un numero en concreto, y colocamos que por lo menos todos tengan 1 baño

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN["bathrooms_text"] = dataN["bathrooms_text"].fillna("1 bath")

#Descripcion: se usa el cuarto método de sustitución de valores, en la columna "bathroom_text"
#pues esta columna contiene strings y se espera que por lo menos se cuente con un baño

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en concreto
dataN["bedrooms"]=data2["bedrooms"].fillna(1)

#Descripcion: Se uso el tercer método de sustitución para los registros de la columna "bedrooms", 
# pues este método nos ayuda a poner un número en concreto, y colocamos que por lo menos todos tengan 1 cuarto

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en concreto
dataN["beds"]=data2["beds"].fillna(1)

#Descripcion: Se uso el tercer método de sustitución para los registros de la columna "beds", 
# pues este método nos ayuda a poner un número en concreto, y colocamos que por lo menos todos tengan 1 cama

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN["price"] = dataN["price"].fillna("$100")

#Descripcion: se usa el cuarto método de sustitución de valores, en la columna "price"
#pues esta columna contiene strings y se espera que por lo menos se cobre alguna comisión para la renta de un cuarto

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN["calendar_updated"] = dataN["calendar_updated"].fillna("within data")

#Descripcion: se usa el cuarto método de sustitución de valores, en la columna "calendar_updated"
#pues esta columna contiene strings, y se informa que no contiene actualizaciones

# %%
#Cuarto Método de sustitución de valores nulos
#Sustituir valores nulos por un string en concreto
dataN["has_availability"] = dataN["has_availability"].fillna("f")

#Descripción: se usa el cuarto método de sustitución de valores, en la columna "has_availability"
#pues esta columna contiene strings, y se informa que es falso o que no está habilitado o disponible

# %%
#Segundo Método de sustitución de valores nulos
#Sustituir valores nulos con mediana
dataN["review_scores_rating"] = dataN["review_scores_rating"].fillna(round(data2["review_scores_rating"].median(),1)) #1 cuántos decimales quiero

#Descripción: se usa el segundo método de sustitución de valores nulos, pues esta sustitución nos ayuda con cuando hay valores atípicos o muy 
# variados, por ejemplo: puede haber reseñas de 1 a 5.

# %%
#Segundo Método de sustitución de valores nulos
#Sustituir valores nulos con mediana
dataN["review_scores_cleanliness"] = dataN["review_scores_cleanliness"].fillna(round(data2["review_scores_cleanliness"].median(),1)) #1 cuántos decimales quiero

#Descripción: se usa el segundo método de sustitución de valores nulos, pues esta sustitución nos ayuda con cuando hay valores atípicos o muy 
# variados, por ejemplo: puede haber reseñas de 1 a 5.

# %%
#Segundo Método de sustitución de valores nulos
#Sustituir valores nulos con mediana
dataN["review_scores_communication"] = dataN["review_scores_communication"].fillna(round(data2["review_scores_communication"].median(),1)) #1 cuántos decimales quiero

#Descripción: se usa el segundo método de sustitución de valores nulos, pues esta sustitución nos ayuda con cuando hay valores atípicos o muy 
# variados, por ejemplo: puede haber reseñas de 1 a 5.

# %%
#Segundo Método de sustitución de valores nulos
#Sustituir valores nulos con mediana
dataN["review_scores_location"] = dataN["review_scores_location"].fillna(round(data2["review_scores_location"].median(),1)) #1 cuántos decimales quiero

#Descripción: se usa el segundo método de sustitución de valores nulos, pues esta sustitución nos ayuda con cuando hay valores atípicos o muy 
# variados, por ejemplo: puede haber reseñas de 1 a 5.

# %%
#Primer Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media

dataN['reviews_per_month']=dataN['reviews_per_month'].fillna(round(data2['reviews_per_month'].mean(),1))

#Descripción: se usa el primer método de sustitución de valores nulos, pues en este caso opté por llenar
#los campos con el promedio de las reseñas por mes, de la columna "reviews_per_month"

# %%
#Identificar valores nulos por dataframe
valores_nulos=dataN.isnull().sum()
valores_nulos
# Out:
# id                             0
# listing_url                    0
# scrape_id                      0
# last_scraped                   0
# source                         0
# name                           0
# neighborhood_overview          0
# picture_url                    0
# host_id                        0
# host_url                       0
# host_name                      0
# host_since                     0
# host_location                  0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_picture_url               0
# host_neighbourhood             0
# host_listings_count            0
# host_total_listings_count      0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# neighbourhood_cleansed         0
# latitude                       0
# ...

# %%
#Identificar valores nulos por dataframe
valores_nulos=dataN.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(0)

# %% [markdown]
# **_Convertir DataSet sin valores nulos a CSV_**

# %%
#Convertir DtaFrame a csv
dataN.to_csv("Albany_sin_nulos.csv")
